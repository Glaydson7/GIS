# %%
from IPython.display import HTML
shell = get_ipython()

def ajustar_tamanho_da_fonte():
    display(HTML("""
    <style>
    body {
        font-size: 22px;
    }
    </style>
    """))

if ajustar_tamanho_da_fonte not in shell.events.callbacks['pre_execute']:
    shell.events.register('pre_execute', ajustar_tamanho_da_fonte)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
from shapely.geometry import Point, LineString, Polygon
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
pontoA = Point(4.4, 8.4)
pontoB = Point(6.4, -10.4)
pontoC = Point(8.4, -5.4)
ponto3D = Point(8.4, -5.4, 100)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
coords = pontoA.coords
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
xy = coords.xy
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
distancia = pontoA.distance(pontoB)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
distancia
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
# 18.90608367695436

# %%
print(pontoA)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
# POINT (4.4 8.4)

# %%
linha = LineString([pontoA,pontoB,pontoC])
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
linha2 = LineString([(5.5, 3.4),(7.8, -25.9),(10, -10)])
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
print(linha2)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
# LINESTRING (5.5 3.4, 7.8 -25.9, 10 -10)

# %%
linha2
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
# <LINESTRING (5.5 3.4, 7.8 -25.9, 10 -10)>

# %%
poligono = Polygon([(5.5, 3.4),(7.8, -25.9),(10, -10)])
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
pontoE = Point(20.4 , 5.4)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
lista_coordenadas = [pontoA, pontoB, pontoC, pontoE]
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
lista = []
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
poligonoCampo = Polygon([(i.x,i.y) for i in lista_coordenadas])
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>

# %%
exterior = poligonoCampo.exterior
print(exterior.length)
# Out:
#     <style>
#     body {
#         font-size: 20px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 12px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
#     <style>
#     body {
#         font-size: 22px;
#     }
#     </style>
# 56.71441793667702
